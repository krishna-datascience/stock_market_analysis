# %% [markdown]
# We will analyse various stocks and answer questions related to stocks like the following
#
#  - What is the trend of price of the stocks over time?
#  - What does the average return of stocks look like?
#  - What does the daily stock return look like?
#  - Plot the moving averages for 20,50,100 and 200 days
#  - Do the stocks have any correlation? (Hint: draw some pairgrid, jointplots, pairplot...)
#
#  Google, apple, walmart, xom, sbux

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

import datetime

#import pandas.io.data as web
import pandas_datareader.data as web
# Out:
# C:\Users\ABHI\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\ABHI\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)
# C:\Users\ABHI\Anaconda3\lib\importlib\_bootstrap.py:219: RuntimeWarning: numpy.ufunc size changed, may indicate binary incompatibility. Expected 192 from C header, got 216 from PyObject
#   return f(*args, **kwds)

# %%
#(start, end)

# %%
start = datetime.datetime(2015,10,10)
end = datetime.date.today()

# %%
google = web.DataReader('GOOG', 'yahoo', start, end)

# %%
google.head()
# Out:
#                   High         Low        Open       Close   Volume   Adj Close
# Date
# 2015-10-09  645.989990  635.317993  640.000000  643.609985  1648700  643.609985
# 2015-10-12  648.500000  639.010010  642.090027  646.669983  1275200  646.669983
# 2015-10-13  657.812012  643.150024  643.150024  652.299988  1807700  652.299988
# 2015-10-14  659.390015  648.849976  653.210022  651.159973  1415500  651.159973
# 2015-10-15  663.130005  654.460022  654.659973  661.739990  1885700  661.739990

# %%
google.tail()
# Out:
#                    High          Low         Open        Close   Volume    Adj Close
# Date
# 2020-02-13  1527.180054  1504.599976  1512.689941  1514.660034   929500  1514.660034
# 2020-02-14  1520.739990  1507.339966  1515.599976  1520.739990  1197800  1520.739990
# 2020-02-18  1531.630005  1512.589966  1515.000000  1519.670044  1120700  1519.670044
# 2020-02-19  1532.105957  1521.400024  1525.069946  1526.689941   949300  1526.689941
# 2020-02-20  1529.640015  1506.819946  1522.000000  1518.150024  1094500  1518.150024

# %%
type(google)
# Out:
# pandas.core.frame.DataFrame

# %%
google.describe()
# Out:
#               High          Low         Open        Close        Volume    Adj Close
# count  1098.000000  1098.000000  1098.000000  1098.000000  1.098000e+03  1098.000000
# mean   1000.069870   983.470033   991.645813   992.149598  1.634187e+06   992.149598
# std     207.379308   203.947707   205.320265   205.893115  7.631692e+05   205.893115
# min     645.989990   635.317993   640.000000   642.609985  3.475000e+05   642.609985
# 25%     787.649994   777.125000   781.737518   783.025009  1.183475e+06   783.025009
# 50%    1034.989990  1013.540009  1022.445007  1023.364990  1.442900e+06  1023.364990
# 75%    1159.339966  1140.515015  1148.407471  1151.945007  1.858150e+06  1151.945007
# max    1532.105957  1521.400024  1525.069946  1526.689941  6.653900e+06  1526.689941

# %%
google.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 1098 entries, 2015-10-09 to 2020-02-20
# Data columns (total 6 columns):
# High         1098 non-null float64
# Low          1098 non-null float64
# Open         1098 non-null float64
# Close        1098 non-null float64
# Volume       1098 non-null int64
# Adj Close    1098 non-null float64
# dtypes: float64(5), int64(1)
# memory usage: 60.0 KB

# %%
sbux = web.DataReader('SBUX', 'yahoo', start, end)

# %%
sbux.head()
# Out:
#                  High        Low       Open      Close     Volume  Adj Close
# Date
# 2015-10-09  60.110001  59.299999  59.470001  60.070000  7969900.0  55.304798
# 2015-10-12  60.889999  60.040001  60.349998  60.540001  6430300.0  55.737514
# 2015-10-13  60.750000  60.020000  60.340000  60.160000  6262800.0  55.387653
# 2015-10-14  60.169998  58.430000  60.000000  58.820000  8365600.0  54.153954
# 2015-10-15  59.830002  58.080002  58.950001  59.689999  9745900.0  54.954933

# %%
xom = web.DataReader('XOM', 'yahoo', start, end)

# %%
apple = web.DataReader('AAPL', 'yahoo', start, end)

# %%
wmt = web.DataReader('WMT', 'yahoo', start, end)

# %%
xom['Adj Close'].plot(legend=True, figsize=(10,6))

# %%
google['Adj Close'].plot(legend=True, color='blue', figsize=(10,6))

# %%
google['Adj Close'].plot(legend=True, color='blue', figsize=(10,6))
xom['Adj Close'].plot(legend=True, color='green', figsize=(10,6))
sbux['Adj Close'].plot(legend=True, color='red', figsize=(10,6))
wmt['Adj Close'].plot(legend=True, color='purple', figsize=(10,6))
apple['Adj Close'].plot(legend=True, color='orange', figsize=(10,6))

# %%
xom['Adj Close'].plot(legend=True, color='green', figsize=(10,6))
sbux['Adj Close'].plot(legend=True, color='red', figsize=(10,6))
wmt['Adj Close'].plot(legend=True, color='purple', figsize=(10,6))
apple['Adj Close'].plot(legend=True, color='orange', figsize=(10,6))

# %%
# let's visualize the daily return for the stocks

# %%
wmt['daily_return'] = wmt['Adj Close'].pct_change()

# %%
wmt.head()
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  daily_return
# Date
# 2015-10-09  67.019997  66.510002  66.940002  66.690002   6754000.0  59.982841           NaN
# 2015-10-12  67.000000  66.580002  66.669998  66.930000   5643900.0  60.198696      0.003599
# 2015-10-13  66.940002  66.260002  66.620003  66.730003   8858400.0  60.018833     -0.002988
# 2015-10-14  67.949997  60.020000  66.610001  60.029999  80898100.0  53.992649     -0.100405
# 2015-10-15  60.470001  58.610001  59.700001  59.330002  46253500.0  53.363052     -0.011661

# %%
wmt['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='blue', legend=True)

# %%
google['daily_return'] = google['Adj Close'].pct_change()

# %%
google.head()
# Out:
#                   High         Low        Open       Close   Volume   Adj Close  daily_return
# Date
# 2015-10-09  645.989990  635.317993  640.000000  643.609985  1648700  643.609985           NaN
# 2015-10-12  648.500000  639.010010  642.090027  646.669983  1275200  646.669983      0.004754
# 2015-10-13  657.812012  643.150024  643.150024  652.299988  1807700  652.299988      0.008706
# 2015-10-14  659.390015  648.849976  653.210022  651.159973  1415500  651.159973     -0.001748
# 2015-10-15  663.130005  654.460022  654.659973  661.739990  1885700  661.739990      0.016248

# %%
google['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='green', legend=True)

# %%
sbux['daily_return'] = sbux['Adj Close'].pct_change()

# %%
sbux.head(10)
# Out:
#                  High        Low       Open      Close      Volume  Adj Close  daily_return
# Date
# 2015-10-09  60.110001  59.299999  59.470001  60.070000   7969900.0  55.304798           NaN
# 2015-10-12  60.889999  60.040001  60.349998  60.540001   6430300.0  55.737514      0.007824
# 2015-10-13  60.750000  60.020000  60.340000  60.160000   6262800.0  55.387653     -0.006277
# 2015-10-14  60.169998  58.430000  60.000000  58.820000   8365600.0  54.153954     -0.022274
# 2015-10-15  59.830002  58.080002  58.950001  59.689999   9745900.0  54.954933      0.014791
# 2015-10-16  60.290001  59.459999  59.959999  59.930000  12860800.0  55.175900      0.004021
# 2015-10-19  61.290001  59.869999  60.130001  60.970001   8117200.0  56.133400      0.017354
# 2015-10-20  61.360001  60.560001  61.220001  60.880001   6089100.0  56.050545     -0.001476
# 2015-10-21  61.119999  60.160000  61.070000  60.529999   6055300.0  55.728294     -0.005749
# 2015-10-22  61.709999  60.169998  60.959999  61.490002   9182000.0  56.612152      0.015860

# %%
sbux['daily_return'].plot(figsize=(13,8), linestyle=':', marker='o', color='red', legend=True)

# %%
stocks = pd.DataFrame({'AAPL': apple['Adj Close'],\
                      'SBUX': sbux['Adj Close'],\
                      'WMT': wmt['Adj Close'],\
                      'GOOG': google['Adj Close'],\
                      'XOM': xom['Adj Close']})

# %%
stocks.head()
# Out:
#                   AAPL       SBUX        WMT        GOOG        XOM
# Date
# 2015-10-09  104.079475  55.304798  59.982841  643.609985  66.045128
# 2015-10-12  103.596771  55.737514  60.198696  646.669983  66.078476
# 2015-10-13  103.773125  55.387653  60.018833  652.299988  65.961807
# 2015-10-14  102.306442  54.153954  53.992649  651.159973  66.795059
# 2015-10-15  103.838120  54.954933  53.363052  661.739990  67.894989

# %%
stocks.tail()
# Out:
#                   AAPL       SBUX         WMT         GOOG        XOM
# Date
# 2020-02-13  324.869995  89.930000  117.440002  1514.660034  60.930000
# 2020-02-14  324.950012  89.279999  117.889999  1520.739990  60.650002
# 2020-02-18  319.000000  89.230003  119.629997  1519.670044  59.880001
# 2020-02-19  323.619995  90.139999  117.680000  1526.689941  60.340000
# 2020-02-20  320.299988  88.599998  117.690002  1518.150024  59.860001

# %%
stocks.plot(figsize=(10,6))

# %%
stock_return = stocks.apply(lambda a: a/a[0])

# %%
stock_return.head()
# Out:
#                 AAPL      SBUX       WMT      GOOG       XOM
# Date
# 2015-10-09  1.000000  1.000000  1.000000  1.000000  1.000000
# 2015-10-12  0.995362  1.007824  1.003599  1.004754  1.000505
# 2015-10-13  0.997057  1.001498  1.000600  1.013502  0.998738
# 2015-10-14  0.982965  0.979191  0.900135  1.011731  1.011355
# 2015-10-15  0.997681  0.993674  0.889639  1.028169  1.028009

# %%
stocks.head()
# Out:
#                   AAPL       SBUX        WMT        GOOG        XOM
# Date
# 2015-10-09  104.079475  55.304798  59.982841  643.609985  66.045128
# 2015-10-12  103.596771  55.737514  60.198696  646.669983  66.078476
# 2015-10-13  103.773125  55.387653  60.018833  652.299988  65.961807
# 2015-10-14  102.306442  54.153954  53.992649  651.159973  66.795059
# 2015-10-15  103.838120  54.954933  53.363052  661.739990  67.894989

# %%
stock_return.tail()
# Out:
#                 AAPL      SBUX       WMT      GOOG       XOM
# Date
# 2020-02-13  3.121365  1.626080  1.957893  2.353382  0.922551
# 2020-02-14  3.122133  1.614326  1.965395  2.362828  0.918312
# 2020-02-18  3.064965  1.613422  1.994404  2.361166  0.906653
# 2020-02-19  3.109355  1.629877  1.961894  2.372073  0.913618
# 2020-02-20  3.077456  1.602031  1.962061  2.358804  0.906350

# %%
stock_return.plot(figsize=(10,8))

# %%
stock_return.head()
# Out:
#                 AAPL      SBUX       WMT      GOOG       XOM
# Date
# 2015-10-09  1.000000  1.000000  1.000000  1.000000  1.000000
# 2015-10-12  0.995362  1.007824  1.003599  1.004754  1.000505
# 2015-10-13  0.997057  1.001498  1.000600  1.013502  0.998738
# 2015-10-14  0.982965  0.979191  0.900135  1.011731  1.011355
# 2015-10-15  0.997681  0.993674  0.889639  1.028169  1.028009

# %%
# sns joinplot

# %%
sns.jointplot('GOOG', 'GOOG', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('SBUX', 'SBUX', stock_return, kind='scatter', color='green')

# %%
sns.jointplot('GOOG', 'SBUX', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('GOOG', 'AAPL', stock_return, kind='scatter', color='blue')

# %%
sns.jointplot('XOM', 'SBUX', stock_return, kind='scatter', color='red')

# %%
sns.jointplot('SBUX', 'WMT', stock_return, kind='scatter', color='green')

# %%
# pairplots

# %%
sns.pairplot(stock_return.dropna())

# %%
# how about parigrid?

# %%
stock_return_fig = sns.PairGrid(stock_return.dropna())
stock_return_fig.map_upper(plt.scatter, color='blue')
stock_return_fig.map_lower(sns.kdeplot, cmap='RdBu')
stock_return_fig.map_diag(plt.hist, bins=23)

# %%
stocks.head()
# Out:
#                   AAPL       SBUX        WMT        GOOG        XOM
# Date
# 2015-10-09  104.079475  55.304798  59.982841  643.609985  66.045128
# 2015-10-12  103.596771  55.737514  60.198696  646.669983  66.078476
# 2015-10-13  103.773125  55.387653  60.018833  652.299988  65.961807
# 2015-10-14  102.306442  54.153954  53.992649  651.159973  66.795059
# 2015-10-15  103.838120  54.954933  53.363052  661.739990  67.894989

# %%
return_pct = stocks.pct_change()

# %%
return_pct.head()
# Out:
#                 AAPL      SBUX       WMT      GOOG       XOM
# Date
# 2015-10-09       NaN       NaN       NaN       NaN       NaN
# 2015-10-12 -0.004638  0.007824  0.003599  0.004754  0.000505
# 2015-10-13  0.001702 -0.006277 -0.002988  0.008706 -0.001766
# 2015-10-14 -0.014134 -0.022274 -0.100405 -0.001748  0.012632
# 2015-10-15  0.014971  0.014791 -0.011661  0.016248  0.016467

# %%
sns.pairplot(return_pct.dropna())

# %%
# moving averages ( rolling window = 20, 50, 100, 200)

# %%
stocks.head()
# Out:
#                   AAPL       SBUX        WMT        GOOG        XOM
# Date
# 2015-10-09  104.079475  55.304798  59.982841  643.609985  66.045128
# 2015-10-12  103.596771  55.737514  60.198696  646.669983  66.078476
# 2015-10-13  103.773125  55.387653  60.018833  652.299988  65.961807
# 2015-10-14  102.306442  54.153954  53.992649  651.159973  66.795059
# 2015-10-15  103.838120  54.954933  53.363052  661.739990  67.894989

# %%
google.head()
# Out:
#                   High         Low        Open       Close   Volume   Adj Close  daily_return
# Date
# 2015-10-09  645.989990  635.317993  640.000000  643.609985  1648700  643.609985           NaN
# 2015-10-12  648.500000  639.010010  642.090027  646.669983  1275200  646.669983      0.004754
# 2015-10-13  657.812012  643.150024  643.150024  652.299988  1807700  652.299988      0.008706
# 2015-10-14  659.390015  648.849976  653.210022  651.159973  1415500  651.159973     -0.001748
# 2015-10-15  663.130005  654.460022  654.659973  661.739990  1885700  661.739990      0.016248

# %%
google['20d'] = google['Close'].rolling(window=20, center=False).mean()

# %%
google['20d'].plot(figsize=(10,6))

# %%
google['20d'].plot(figsize=(10,6))
google['Close'].plot(figsize=(10,6), color='red')

# %%
apple['20d'] = apple['Close'].rolling(window=20, center=False).mean()

# %%
apple['20d'].plot(figsize=(10,6), color='blue')

# %%
apple['20d'].plot(figsize=(10,6), color='red')
apple['Close'].plot(figsize=(10,6), color='blue')

# %%
# 50 days mov av

# %%
apple['50d'] = apple['Close'].rolling(window=50, center=False).mean()

# %%
apple['50d'].plot(figsize=(10,6), color='red')
apple['Close'].plot(figsize=(10,6), color='blue')

# %%
# 20, 50, 100, 200

# %%
google['50d'] = google['Close'].rolling(window=50, center=False).mean()

# %%
google['100d'] = google['Close'].rolling(window=100, center=False).mean()

# %%
google['200d'] = google['Close'].rolling(window=200, center=False).mean()

# %%
google['Close'].plot(figsize=(10,6), color='blue',legend=True)
google['20d'].plot(figsize=(10,6), color='red', legend=True)
google['50d'].plot(figsize=(10,6), color='green', legend=True)
google['100d'].plot(figsize=(10,6), color='orange', legend=True)
google['200d'].plot(figsize=(10,6), color='purple', legend=True)

# %%
google['Close'].plot(figsize=(10,6), color='blue',legend=True)

google['200d'].plot(figsize=(10,6), color='purple', legend=True)

# %%
xom['20d'] = xom['Close'].rolling(window=20, center=False).mean()

# %%
xom['Close'].plot(figsize=(10,6),color='red',legend=True)
xom['20d'].plot(figsize=(10,6), color='blue', legend=True)
